# %%
from src.dataset import get_data
import matplotlib.pyplot as plt
import numpy as np
import random
# Out:
# 2025-06-04 10:32:48.532 | INFO     | src.config:<module>:11 - PROJ_ROOT path is: C:\Git\fmnist-classification

# %%
train_loader, val_loader, test_loader = get_data()

# %%
def visualize_random_image(train_loader):
    class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
                   'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
    
    data_iter = iter(train_loader)
    images, labels = next(data_iter)
    
    idx = random.randint(0, len(images) - 1)
    image = images[idx]
    label = labels[idx]
    
    image_np = image.permute(1, 2, 0).numpy()
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image_np = (image_np * std) + mean
    
    image_np = np.clip(image_np, 0, 1)  
    
    plt.figure(figsize=(6, 6))
    plt.imshow(image_np, cmap='gray')
    plt.title(f'Class: {class_names[label]} (Label: {label})')
    plt.axis('off')
    plt.show()

# %%
visualize_random_image(train_loader)
